# %%
import seaborn as sns
import pandas as pd

# %%
seed_565 = [62.807, 63.9649, 67, 68.9298, 68.4211, 69.8421, 71.2105, 69.807, 70.8596, 71.2982]
seed_965 = [60.8596, 63.5789, 67.3684, 69.1579, 68.386, 68.9474, 69.7895, 69.3158, 70.1053, 70.7193]
seed_388 = [60.9298, 65.8596, 65.9649, 68.3684, 69.7193, 69.1404, 70.5263, 71, 71, 71]

accuracies = pd.DataFrame({'seed_565':seed_565, 'seed_965': seed_965, 'seed_388': seed_388})
sns.lineplot(data=accuracies)
# Out:
# <AxesSubplot:>
