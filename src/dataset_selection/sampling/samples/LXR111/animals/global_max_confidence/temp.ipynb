# %%
import pickle

with open('seed_388/budget_10.pkl', 'rb') as f:
    x = pickle.load(f)

# %%
with open('seed_565/budget_10.pkl', 'rb') as f:
    y = pickle.load(f)

# %%
y
# Out:
# [533504003,
#  477782029,
#  490111002,
#  288383002,
#  264020001,
#  324436002,
#  530686000,
#  168190003,
#  307069001,
#  353149001,
#  445522001,
#  86098004,
#  29180000,
#  70353001,
#  184443000,
#  514171001,
#  194896006,
#  31269002,
#  492282000,
#  287695002,
#  116900003,
#  203768000,
#  432120000,
#  18424004,
#  101581002,
#  337314000,
#  11682003,
#  337314004,
#  82338005,
#  134562005,
#  417825001,
#  442614001,
#  6603000,
#  540107001,
#  495051001,
#  6603002,
#  415990008,
#  327328000,
#  219423001,
#  560628007,
#  274334001,
#  342942003,
#  190579001,
#  261448000,
#  214131013,
#  157213000,
#  155165001,
#  191005010,
#  180167006,
#  547783008,
#  245105000,
#  354075000,
#  390341000,
#  230597003,
#  390341004,
#  121242002,
#  398746003,
#  117146004,
#  372122004,
#  372548006,
#  95257000,
#  142574000,
#  561390001,
#  115950002,
#  569582002,
#  334275003,
#  61506000,
#  571671000,
#  514327002,
#  393282011,
#  349676002,
#  476652003,
# ...

# %%
x
# Out:
# [533504003,
#  477782029,
#  490111002,
#  288383002,
#  264020001,
#  324436002,
#  530686000,
#  168190003,
#  307069001,
#  353149001,
#  445522001,
#  86098004,
#  29180000,
#  70353001,
#  184443000,
#  514171001,
#  194896006,
#  31269002,
#  492282000,
#  287695002,
#  116900003,
#  203768000,
#  432120000,
#  18424004,
#  101581002,
#  337314000,
#  11682003,
#  337314004,
#  82338005,
#  134562005,
#  417825001,
#  442614001,
#  6603000,
#  540107001,
#  495051001,
#  6603002,
#  415990008,
#  327328000,
#  219423001,
#  560628007,
#  274334001,
#  342942003,
#  190579001,
#  261448000,
#  214131013,
#  157213000,
#  155165001,
#  191005010,
#  180167006,
#  547783008,
#  245105000,
#  354075000,
#  390341000,
#  230597003,
#  390341004,
#  121242002,
#  398746003,
#  117146004,
#  372122004,
#  372548006,
#  95257000,
#  142574000,
#  561390001,
#  115950002,
#  569582002,
#  334275003,
#  61506000,
#  571671000,
#  514327002,
#  393282011,
#  349676002,
#  476652003,
# ...
